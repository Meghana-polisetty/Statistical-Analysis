# %% [markdown]
# # D Tale

# %%
# !pip install dtale
# Out:
# Requirement already satisfied: dtale in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (2.7.1)
# Requirement already satisfied: kaleido in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: future>=0.14.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.18.2)
# Requirement already satisfied: dash-bootstrap-components in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.2.1)
# Requirement already satisfied: cycler in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.10.0)
# Requirement already satisfied: xarray in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.20.2)
# Requirement already satisfied: dash-daq in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.5.0)
# Requirement already satisfied: xlrd in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: flask-ngrok in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.0.25)
# Requirement already satisfied: requests in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.26.0)
# Requirement already satisfied: Flask-Compress in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.12)
# Requirement already satisfied: six in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.16.0)
# Requirement already satisfied: Flask in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.1.2)
# Requirement already satisfied: scipy in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.7.1)
# Requirement already satisfied: numpy in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.20.3)
# Requirement already satisfied: et-xmlfile in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.1.0)
# Requirement already satisfied: missingno<=0.4.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.4.2)
# Requirement already satisfied: networkx in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.6.3)
# Requirement already satisfied: strsimpy in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: scikit-learn in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.0.2)
# Requirement already satisfied: openpyxl in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (3.0.9)
# Requirement already satisfied: itsdangerous in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: plotly>=5.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (5.9.0)
# Requirement already satisfied: seaborn in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.11.2)
# Requirement already satisfied: matplotlib in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (3.4.3)
# Requirement already satisfied: dash-colorscales in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.0.4)
# Requirement already satisfied: lz4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (4.0.2)
# Requirement already satisfied: certifi in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2021.10.8)
# Requirement already satisfied: statsmodels in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.12.2)
# Requirement already satisfied: pandas in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.3.4)
# Requirement already satisfied: squarify in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.4.3)
# Requirement already satisfied: dash>=2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.6.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (2.0.2)
# Requirement already satisfied: click>=5.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask->dtale) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Requirement already satisfied: brotli in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (1.26.7)
# Requirement already satisfied: joblib>=0.11 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->dtale) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from statsmodels->dtale) (0.5.2)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dtale
import xarray as xr
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Meghanas-MacBook-Air.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Pandas-Profiling

# %%
# !pip install pandas.profiling
# Out:
# Requirement already satisfied: pandas.profiling in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (3.2.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (2.26.0)
# Requirement already satisfied: missingno>=0.4.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.4.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.2.0)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (6.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (3.4.3)
# Requirement already satisfied: multimethod>=1.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.8)
# Collecting markupsafe~=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.3.4)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.9.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.20.3)
# Requirement already satisfied: joblib~=1.1.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.1.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.7.4)
# Requirement already satisfied: scipy>=1.4.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (1.7.1)
# Requirement already satisfied: phik>=0.11.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.12.2)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (2.11.3)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (4.62.3)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.11.2)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas.profiling) (0.1.12)
# Requirement already satisfied: attrs>=19.3.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas.profiling) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas.profiling) (2.6.3)
# Requirement already satisfied: Pillow in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas.profiling) (8.4.0)
# Requirement already satisfied: imagehash in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas.profiling) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas.profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas.profiling) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas.profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas.profiling) (0.10.0)
# Requirement already satisfied: six in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas.profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas.profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas.profiling) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas.profiling) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas.profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas.profiling) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas.profiling) (2021.10.8)
# Requirement already satisfied: PyWavelets in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas.profiling) (1.1.1)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# cookiecutter 1.7.2 requires MarkupSafe<2.0.0, but you have markupsafe 2.1.1 which is incompatible.
# Successfully installed markupsafe-2.1.1

# %%
import seaborn as sns
df1 = sns.load_dataset('tips')

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df1,title = 'Pandas Profiling Report',explorative = True)
profile.to_widgets()
# Out:
# 2022-08-11 15:04:04,005 - INFO     - Pandas backend loaded 1.3.4
# 2022-08-11 15:04:04,010 - INFO     - Numpy backend loaded 1.20.3
# 2022-08-11 15:04:04,011 - INFO     - Pyspark backend NOT loaded
# 2022-08-11 15:04:04,012 - INFO     - Python backend loaded
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# # SweetVIZ

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
#      |████████████████████████████████| 15.1 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.43.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (2.11.3)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (1.3.4)
# Requirement already satisfied: scipy>=1.3.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (1.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from sweetviz) (3.4.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=1.2.0->sweetviz) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (8.4.0)
# Requirement already satisfied: six in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.9.0 sweetviz-2.1.4

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html('Sweet Viz.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Sweet Viz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
