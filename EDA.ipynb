# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (3.2.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: markupsafe~=2.1.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: missingno>=0.4.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.5.1)
# Requirement already satisfied: multimethod>=1.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.8)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.3.4)
# Requirement already satisfied: phik>=0.11.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.20.3)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: joblib~=1.1.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (1.1.0)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (3.4.3)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas-profiling) (2.26.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (2.6.3)
# Requirement already satisfied: Pillow in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (8.4.0)
# Requirement already satisfied: imagehash in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: six in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling) (2021.10.8)
# Requirement already satisfied: PyWavelets in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.1.1)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df = pd.read_csv("FitBit data.csv")
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
pip install MarkupSafe
# Out:
# Requirement already satisfied: MarkupSafe in /Users/maggie/opt/anaconda3/lib/python3.9/site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#pandas profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df,title = 'Pandas Profiling Report',explorative = True)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
df.shape
# Out:
# (457, 15)

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.000000                  0.020000
# 75%                    0.000000            1.310000                  0.670000
# max                    6.727057           21.920000                  6.400000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           457.000000               457.000000         457.000000
# mean              2.890197                 0.001904          16.623632
# std               2.237523                 0.008487          28.919704
# min               0.000000                 0.000000           0.000000
# 25%               0.870000                 0.000000           0.000000
# 50%               2.930000                 0.000000           0.000000
# 75%               4.460000                 0.000000          25.000000
# max              12.510000                 0.100000         202.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           457.000000            457.000000        457.000000
# mean             13.070022            170.070022        995.282276
# std              36.208635            122.205372        337.021404
# min               0.000000              0.000000         32.000000
# 25%               0.000000             64.000000        728.000000
# 50%               1.000000            181.000000       1057.000000
# 75%              16.000000            257.000000       1285.000000
# max             660.000000            720.000000       1440.000000
#
#           Calories
# count   457.000000
# mean   2189.452954
# std     815.484523
# min       0.000000
# 25%    1776.000000
# 50%    2062.000000
# 75%    2667.000000
# max    4562.000000

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
df.isnull()
# Out:
#         Id  ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    False         False       False          False            False
# 1    False         False       False          False            False
# 2    False         False       False          False            False
# 3    False         False       False          False            False
# 4    False         False       False          False            False
# ..     ...           ...         ...            ...              ...
# 452  False         False       False          False            False
# 453  False         False       False          False            False
# 454  False         False       False          False            False
# 455  False         False       False          False            False
# 456  False         False       False          False            False
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       False               False                     False
# 1                       False               False                     False
# 2                       False               False                     False
# 3                       False               False                     False
# 4                       False               False                     False
# ..                        ...                 ...                       ...
# 452                     False               False                     False
# 453                     False               False                     False
# 454                     False               False                     False
# 455                     False               False                     False
# 456                     False               False                     False
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                  False                    False              False
# 1                  False                    False              False
# 2                  False                    False              False
# 3                  False                    False              False
# 4                  False                    False              False
# ..                   ...                      ...                ...
# 452                False                    False              False
# 453                False                    False              False
# 454                False                    False              False
# 455                False                    False              False
# 456                False                    False              False
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                  False                 False             False     False
# 1                  False                 False             False     False
# 2                  False                 False             False     False
# 3                  False                 False             False     False
# 4                  False                 False             False     False
# ..                   ...                   ...               ...       ...
# 452                False                 False             False     False
# 453                False                 False             False     False
# 454                False                 False             False     False
# 455                False                 False             False     False
# 456                False                 False             False     False
#
# [457 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df['ActivityDate'].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
df['Day'] = pd.DatetimeIndex(df['ActivityDate']).day
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      date  Day
# 0      25   25
# 1      26   26
# 2      27   27
# 3      28   28
# 4      29   29
# ..    ...  ...
# 452     8    8
# 453     9    9
# 454    10   10
# 455    11   11
# 456    12   12
#
# [457 rows x 17 columns]

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                        object
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# date                        datetime64[ns]
# dtype: object

# %%
df['Month'] = pd.DatetimeIndex(df['ActivityDate']).month
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      date  Day  Month
# 0      25   25      3
# 1      26   26      3
# 2      27   27      3
# 3      28   28      3
# 4      29   29      3
# ..    ...  ...    ...
# 452     8    8      4
# 453     9    9      4
# 454    10   10      4
# 455    11   11      4
# 456    12   12      4
#
# [457 rows x 18 columns]

# %%
df['Year'] = pd.DatetimeIndex(df['ActivityDate']).year
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      date  Day  Month  Year
# 0      25   25      3  2016
# 1      26   26      3  2016
# 2      27   27      3  2016
# 3      28   28      3  2016
# 4      29   29      3  2016
# ..    ...  ...    ...   ...
# 452     8    8      4  2016
# 453     9    9      4  2016
# 454    10   10      4  2016
# 455    11   11      4  2016
# 456    12   12      4  2016
#
# [457 rows x 19 columns]

# %%
df.drop(['date'],axis = 1, inplace = True)

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      Day  Month  Year
# 0     25      3  2016
# 1     26      3  2016
# 2     27      3  2016
# 3     28      3  2016
# 4     29      3  2016
# ..   ...    ...   ...
# 452    8      4  2016
# 453    9      4  2016
# 454   10      4  2016
# 455   11      4  2016
# 456   12      4  2016
#
# [457 rows x 18 columns]

# %%
df[['ActivityDate','Day','Month','Year']]
# Out:
#     ActivityDate  Day  Month  Year
# 0      3/25/2016   25      3  2016
# 1      3/26/2016   26      3  2016
# 2      3/27/2016   27      3  2016
# 3      3/28/2016   28      3  2016
# 4      3/29/2016   29      3  2016
# ..           ...  ...    ...   ...
# 452     4/8/2016    8      4  2016
# 453     4/9/2016    9      4  2016
# 454    4/10/2016   10      4  2016
# 455    4/11/2016   11      4  2016
# 456    4/12/2016   12      4  2016
#
# [457 rows x 4 columns]

# %%
df.drop(['ActivityDate'],axis = 1)
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      Day  Month  Year
# 0     25      3  2016
# 1     26      3  2016
# 2     27      3  2016
# 3     28      3  2016
# 4     29      3  2016
# ..   ...    ...   ...
# 452    8      4  2016
# 453    9      4  2016
# 454   10      4  2016
# 455   11      4  2016
# 456   12      4  2016
#
# [457 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
sns.boxplot(x = 'Day', y = 'Calories', data = df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Calories'>

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      Day  Month  Year
# 0     25      3  2016
# 1     26      3  2016
# 2     27      3  2016
# 3     28      3  2016
# 4     29      3  2016
# ..   ...    ...   ...
# 452    8      4  2016
# 453    9      4  2016
# 454   10      4  2016
# 455   11      4  2016
# 456   12      4  2016
#
# [457 rows x 18 columns]

# %%
df['Week'] = pd.DatetimeIndex(df['ActivityDate']).week
# Out:
# /var/folders/1v/x5wmbpv968z1bmkh4vxwvqt80000gn/T/ipykernel_28405/3533062942.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['Week'] = pd.DatetimeIndex(df['ActivityDate']).week

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      Day  Month  Year  Week
# 0     25      3  2016    12
# 1     26      3  2016    12
# 2     27      3  2016    12
# 3     28      3  2016    13
# 4     29      3  2016    13
# ..   ...    ...   ...   ...
# 452    8      4  2016    14
# 453    9      4  2016    14
# 454   10      4  2016    14
# 455   11      4  2016    15
# 456   12      4  2016    15
#
# [457 rows x 19 columns]

# %%
pd.to_datetime(df['ActivityDate'])
# Out:
# 0     2016-03-25
# 1     2016-03-26
# 2     2016-03-27
# 3     2016-03-28
# 4     2016-03-29
#          ...
# 452   2016-04-08
# 453   2016-04-09
# 454   2016-04-10
# 455   2016-04-11
# 456   2016-04-12
# Name: ActivityDate, Length: 457, dtype: datetime64[ns]

# %%
df['date_time'] = pd.to_datetime(df['ActivityDate'])

# %%
df['week_name'] = df['date_time'].dt.day_name()

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  ...  FairlyActiveMinutes  \
# 0                   4.07                     0.00  ...                   12
# 1                   3.91                     0.00  ...                   17
# 2                   3.71                     0.00  ...                    5
# 3                   4.95                     0.00  ...                   20
# 4                   4.61                     0.00  ...                   28
# ..                   ...                      ...  ...                  ...
# 452                 8.62                     0.00  ...                   29
# 453                 8.02                     0.00  ...                    9
# 454                 4.46                     0.00  ...                   46
# 455                 6.37                     0.01  ...                    7
# 456                 1.78                     0.00  ...                    0
#
#      LightlyActiveMinutes  SedentaryMinutes  Calories  Day  Month  Year  Week  \
# 0                     205               804      1819   25      3  2016    12
# 1                     274               588      2154   26      3  2016    12
# 2                     268               605      1944   27      3  2016    12
# 3                     224              1080      1932   28      3  2016    13
# 4                     243               763      1886   29      3  2016    13
# ..                    ...               ...       ...  ...    ...   ...   ...
# 452                   359               982      4196    8      4  2016    14
# 453                   289              1052      3841    9      4  2016    14
# 454                   211              1055      4526   10      4  2016    14
# 455                   225              1190      2820   11      4  2016    15
# 456                    58               531       938   12      4  2016    15
#
#      date_time week_name
# 0   2016-03-25    Friday
# 1   2016-03-26  Saturday
# 2   2016-03-27    Sunday
# 3   2016-03-28    Monday
# 4   2016-03-29   Tuesday
# ..         ...       ...
# 452 2016-04-08    Friday
# 453 2016-04-09  Saturday
# 454 2016-04-10    Sunday
# 455 2016-04-11    Monday
# 456 2016-04-12   Tuesday
#
# [457 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
sns.boxplot(x = 'week_name', y = 'Calories', data = df)
# Out:
# <AxesSubplot:xlabel='week_name', ylabel='Calories'>

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Day', 'Month',
#        'Year', 'Week', 'date_time', 'week_name'],
#       dtype='object')

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(x = 'Calories', y = 'TotalSteps', data = df)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='TotalSteps'>

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Day', 'Month',
#        'Year', 'Week', 'date_time', 'week_name'],
#       dtype='object')
